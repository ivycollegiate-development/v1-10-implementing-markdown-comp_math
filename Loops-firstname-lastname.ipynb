# %%
for i in range(5):
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# What if we start at a different number?
for i in range(2,8):  # Students fill in: start at 2, end at 7
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
