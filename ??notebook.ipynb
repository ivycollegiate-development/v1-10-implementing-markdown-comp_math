# %% [markdown]
# # Data Analysis Notebook

# %% [markdown]
# This notebook converts a Python script into Jupyter format.

# %%
def add(a, b):
    return a + b

# %%
print("Hello Jupyter")

# %%
import math
math.sqrt(16)

# %% [markdown]
# ## Function Example

# %%
add(3, 5)

# %% [markdown]
# This concludes the basic demonstration.
